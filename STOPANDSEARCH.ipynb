# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import datetime as dt
df = pd.read_json("https://data.police.uk/api/stops-force?force=cleveland&date=2020-07")

# %%
df.head()
# Out:
#   age_range                       outcome  involved_person  \
# 0      None  A no further action disposal             True
# 1     25-34                                           True
# 2     10-17  A no further action disposal             True
# 3     18-24      Khat or Cannabis warning             True
# 4     10-17  A no further action disposal             True
#
#                               self_defined_ethnicity  gender  \
# 0                                               None    None
# 1  White - English/Welsh/Scottish/Northern Irish/...    Male
# 2                                               None    Male
# 3                    Other ethnic group - Not stated    Male
# 4                                               None  Female
#
#                              legislation  outcome_linked_to_object_of_search  \
# 0  Misuse of Drugs Act 1971 (section 23)                                 1.0
# 1  Misuse of Drugs Act 1971 (section 23)                                 1.0
# ...

# %%
df.tail()
# Out:
#     age_range                       outcome  involved_person  \
# 539   over 34  A no further action disposal             True
# 540      None  A no further action disposal             True
# 541     25-34  A no further action disposal             True
# 542     25-34  A no further action disposal             True
# 543     18-24  A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 539  White - English/Welsh/Scottish/Northern Irish/...   Male
# 540                                               None   None
# 541  White - English/Welsh/Scottish/Northern Irish/...   Male
# 542  White - English/Welsh/Scottish/Northern Irish/...   Male
# 543  White - English/Welsh/Scottish/Northern Irish/...   Male
#
#                                            legislation  \
# 539  Police and Criminal Evidence Act 1984 (section 1)
# 540              Misuse of Drugs Act 1971 (section 23)
# ...

# %%
df.sort_values(by = "datetime", ascending = True, inplace = True)

# %%
df.head()
# Out:
#    age_range                       outcome  involved_person  \
# 19   over 34  A no further action disposal             True
# 20   over 34  A no further action disposal             True
# 21     10-17  A no further action disposal             True
# 22     25-34                        Arrest             True
# 23     25-34                        Arrest             True
#
#                                self_defined_ethnicity gender  \
# 19  White - English/Welsh/Scottish/Northern Irish/...   None
# 20  White - English/Welsh/Scottish/Northern Irish/...   Male
# 21  Mixed/Multiple ethnic groups - Any other Mixed...   Male
# 22  White - English/Welsh/Scottish/Northern Irish/...   Male
# 23  White - English/Welsh/Scottish/Northern Irish/...   Male
#
#                                           legislation  \
# 19  Police and Criminal Evidence Act 1984 (section 1)
# 20  Police and Criminal Evidence Act 1984 (section 1)
# 21  Police and Criminal Evidence Act 1984 (section 1)
# ...

# %%
df.tail()
# Out:
#     age_range                       outcome  involved_person  \
# 539   over 34  A no further action disposal             True
# 540      None  A no further action disposal             True
# 541     25-34  A no further action disposal             True
# 542     25-34  A no further action disposal             True
# 543     18-24  A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 539  White - English/Welsh/Scottish/Northern Irish/...   Male
# 540                                               None   None
# 541  White - English/Welsh/Scottish/Northern Irish/...   Male
# 542  White - English/Welsh/Scottish/Northern Irish/...   Male
# 543  White - English/Welsh/Scottish/Northern Irish/...   Male
#
#                                            legislation  \
# 539  Police and Criminal Evidence Act 1984 (section 1)
# 540              Misuse of Drugs Act 1971 (section 23)
# ...

# %%
df.describe()
# Out:
#        outcome_linked_to_object_of_search  \
# count                          122.000000
# mean                             0.836066
# std                              0.371743
# min                              0.000000
# 25%                              1.000000
# 50%                              1.000000
# 75%                              1.000000
# max                              1.000000
#
#        removal_of_more_than_outer_clothing  operation  operation_name
# count                                  0.0        0.0             0.0
# mean                                   NaN        NaN             NaN
# std                                    NaN        NaN             NaN
# min                                    NaN        NaN             NaN
# 25%                                    NaN        NaN             NaN
# 50%                                    NaN        NaN             NaN
# 75%                                    NaN        NaN             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 544 entries, 19 to 543
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   age_range                            477 non-null    object
#  1   outcome                              544 non-null    object
#  2   involved_person                      544 non-null    bool
#  3   self_defined_ethnicity               440 non-null    object
#  4   gender                               475 non-null    object
#  5   legislation                          539 non-null    object
#  6   outcome_linked_to_object_of_search   122 non-null    float64
#  7   datetime                             544 non-null    datetime64[ns, UTC]
#  8   removal_of_more_than_outer_clothing  0 non-null      float64
#  9   outcome_object                       544 non-null    object
#  10  location                             266 non-null    object
# ...

# %%
r = requests.get("https://data.police.uk/api/stops-force?force=cleveland&date=2020-06")
x = r.json()
dff = pd.read_json(json.dumps(x))

# %%
dff.head()
# Out:
#   age_range                       outcome  involved_person  \
# 0   over 34  A no further action disposal             True
# 1   over 34  A no further action disposal             True
# 2   over 34                        Arrest             True
# 3   over 34                        Arrest             True
# 4   over 34  A no further action disposal             True
#
#                               self_defined_ethnicity  gender  \
# 0  White - English/Welsh/Scottish/Northern Irish/...    Male
# 1  White - English/Welsh/Scottish/Northern Irish/...    Male
# 2  White - English/Welsh/Scottish/Northern Irish/...    Male
# 3  White - English/Welsh/Scottish/Northern Irish/...    Male
# 4  White - English/Welsh/Scottish/Northern Irish/...  Female
#
#                                          legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2  Police and Criminal Evidence Act 1984 (section 1)
# ...

# %%
df = pd.read_json("https://data.police.uk/api/stops-force?force=cleveland&date=2020-07")
df = pd.DataFrame(df)
df.head()
df.sort_values(by = "datetime", ascending = True, inplace = True)
#df.involved_person.astype(str)
#cleveland_SS = df.involved_person.astype(str).contains(True)
cleveland_SS = len(df["involved_person"])
total = print(cleveland_SS)
dfff = df.groupby("age_range")
dfff.head()

dfff.plot(kind = "line", x = "age_range", y = "officer_defined_ethnicity")
#cleveland_SS = df.involved_person.str.contains("True")
# #print(len(cleveland_SS))
# Out:
# 544
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in f(self)
#     462         def f(self):
# ...

# %%
df.age_range.unique()
# Out:
# array(['over 34', '10-17', '25-34', '18-24', None], dtype=object)

# %%
police = requests.get("https://data.police.uk/api/stops-force?force=cleveland&date=2020-07")
print(police.statuscode)

# %%
df.plot(kind = "line", x = "age_range", y = "officer_defined_ethnicity")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-9b8fe4368b7f> in <module>
# ----> 1 df.plot(kind = "line", x = "age_range", y = "officer_defined_ethnicity")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...
